# %%
from convertToDictionaries import csv_to_list_of_dictionaries
list_of_dicts = csv_to_list_of_dictionaries('/Users/zcalabrese/Google Drive/development/pythonTools/testcsv.csv')

# %%
import pandas

# %%
df = pandas.DataFrame(list_of_dicts)

# %%
print df
# Out:
#       Advisor CRD           City  \
# 0
# 1         2788548        Madison
# 2                     Washington
# 3                       Prescott
# 4                       Anywhere
# 5         1712799   Philadelphia
# 6
# 7
# 8
# 9
# 10
# 11
# 12        4060501
# 13                     Charlotte
# 14
# 15                  Philadelphia
# 16                     Honesdale
# 17                        Monroe
# 18
# 19                       Wexford
# 20                       Buffalo
# 21
# 22                     Wellesley
# 23                    Orwigsburg
# 24                     Frontenac
# 25                     Bluefield
# 26                     Attleboro
# 27                     Cleveland
# 28                       Mankato
# 29                    Wilmington
# ...           ...            ...
# 11236                 Wilmington
# 11237
# 11238
# 11239
# 11240
# 11241
# 11242              San Francisco
# 11243
# 11244
# 11245
# 11246
# 11247
# 11248
# 11249
# ...

# %%
df['Phone']['Email'][:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-bea793e41e73> in <module>()
# ----> 1 df['Phone']['Email'][:10]
#
# /Users/zcalabrese/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     507     def __getitem__(self, key):
#     508         try:
# --> 509             result = self.index.get_value(self, key)
#     510
#     511             if not np.isscalar(result):
#
# /Users/zcalabrese/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1415
#    1416         try:
# -> 1417             return self._engine.get_value(s, k)
#    1418         except KeyError as e1:
#    1419             if len(self) > 0 and self.inferred_type in ['integer','boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3109)()
#
# ...

# %%
df['Email']

# %%
df.dtypes
# Out:
# Advisor CRD                 object
# City                        object
# Company / Account           object
# Email                       object
# First Name                  object
# Last Name                   object
# Lead ID                     object
# Meridian Email              object
# Meridian IQ Profile Link    object
# Meridian Mailing City       object
# Meridian Mailing State      object
# Meridian Mailing ZipCode    object
# Meridian Phone Number       object
# Meridian Street Address     object
# Phone                       object
# State/Province              object
# Street                      object
# Zip/Postal Code             object
# dtype: object

# %%
df.head()

# %%
df.tail()

# %%
df.index

# %%
df.columns
# Out:
# Index([u'Advisor CRD', u'City', u'Company / Account', u'Email', u'First Name', u'Last Name', u'Lead ID', u'Meridian Email', u'Meridian IQ Profile Link', u'Meridian Mailing City', u'Meridian Mailing State', u'Meridian Mailing ZipCode', u'Meridian Phone Number', u'Meridian Street Address', u'Phone', u'State/Province', u'Street', u'Zip/Postal Code'], dtype='object')

# %%
df.values

# %%
df['Email'].describe

# %%
df.T

# %%
df['Advisor CRD'].mean

# %%
df[:20]

# %%
df[:5]
